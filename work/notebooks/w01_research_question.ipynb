# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"Im choosing Lane 1 because I want to understand which signals are actually associated with visibility and clicks in this data. This gives me the idea that other lanes all depend on."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"Unit of analysis: one content page (one row = one content_id)"
"Question: Which observable signals are associated with a page's visibility, clicks, or performance trend"
"Decision: which signals the content team should pay attention to when seeing pages"
"Action: prioritize which type of intervention based on which signal shows the strongest relationship"
"Cost of a wrong call: if I claim a signal matters when it's a irrelevant, the team could spend hours fixing something that was never the problem"

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/f230865-netizen/FlyRankAI-Assignment-1/main/data/raw/content_refresh_anonymized.csv")  # adjust path to your notebook location

print("Rows:", len(df))
print(df['trend_direction'].value_counts())

# CTR by position bucket
df['pos_bucket'] = pd.cut(df['avg_position'], bins=[0,3,10,20,50,1000])
print(df.groupby('pos_bucket', observed=True)['ctr'].mean())
# Out:
# Rows: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# pos_bucket
# (0, 3]        2.714303
# (3, 10]       0.651045
# (10, 20]      0.323443
# (20, 50]      0.222345
# (50, 1000]    0.150784
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"These are observed from a single 90-day anonymized snapshot. I can say position and CTR move together strongly. I cannot say improving a page's position will cause a proportional CTR increase.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
